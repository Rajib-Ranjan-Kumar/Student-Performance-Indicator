# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,LogisticRegression,Ridge
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix,classification_report,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv("stud.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
x=df.drop(columns=['math_score'],axis=1)

# %%
y=df['math_score']

# %%
x
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  reading_score  writing_score
# 0                      none             72             74
# 1                 completed             90             88
# 2                      none             95             93
# 3                      none             57             44
# 4                      none             78             75
# ..                      ...            ...            ...
# 995               completed             99             95
# 996                    none             55             55
# 997               completed             71             65
# 998               completed             78             77
# 999                    none             86             86
#
# [1000 rows x 7 columns]

# %%
categorical_feature=[column for column in df.columns if df[column].dtype=='O']
numerical_feature=[column for column in x.columns if df[column].dtype!='O']

# %%
x,y
# Out:
# (     gender race_ethnicity parental_level_of_education         lunch  \
#  0    female        group B           bachelor's degree      standard
#  1    female        group C                some college      standard
#  2    female        group B             master's degree      standard
#  3      male        group A          associate's degree  free/reduced
#  4      male        group C                some college      standard
#  ..      ...            ...                         ...           ...
#  995  female        group E             master's degree      standard
#  996    male        group C                 high school  free/reduced
#  997  female        group C                 high school  free/reduced
#  998  female        group D                some college      standard
#  999  female        group D                some college  free/reduced
#
#      test_preparation_course  reading_score  writing_score
#  0                      none             72             74
#  1                 completed             90             88
#  2                      none             95             93
#  3                      none             57             44
#  4                      none             78             75
#  ..                      ...            ...            ...
#  995               completed             99             95
#  996                    none             55             55
#  997               completed             71             65
#  998               completed             78             77
#  999                    none             86             86
#
#  [1000 rows x 7 columns],
#  0      72
#  1      69
#  2      90
#  3      47
#  4      76
#         ..
#  995    88
#  996    62
#  997    59
#  998    68
#  999    77
#  Name: math_score, Length: 1000, dtype: int64)

# %%
def metrics_evaluation(y_predict,ytest):
    mse=mean_squared_error(ytest,y_predict)
    r2=r2_score(ytest,y_predict)
    mae=mean_absolute_error(ytest,y_predict)
    return mse,r2,mae

# %%
models={
    "LinearRegression":LinearRegression(),
    "LogisticRegression":LogisticRegression(),
    "Ridge":Ridge(),
    "SVR":SVR(),
    "NaiveBayes":GaussianNB(),
    "KNeighborsRegressor":KNeighborsRegressor(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor(),
    "AdaBoostRegressor":AdaBoostRegressor(),
    "XGBRegressor":XGBRegressor()
}

# %%
ohe=OneHotEncoder()
ss=StandardScaler()
preprocessing=ColumnTransformer(
    [
    ("OneHotEncoder",ohe,categorical_feature),
    ("StandardScaler",ss,numerical_feature)
    ]
)

# %%
x=preprocessing.fit_transform(x)

# %%
x=pd.DataFrame(data=x,columns=preprocessing.get_feature_names_out())

# %%
x.shape
# Out:
# (1000, 19)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
x.iloc[750:]
# Out:
#      OneHotEncoder__gender_female  OneHotEncoder__gender_male  \
# 750                           0.0                         1.0
# 751                           0.0                         1.0
# 752                           0.0                         1.0
# 753                           1.0                         0.0
# 754                           0.0                         1.0
# ..                            ...                         ...
# 995                           1.0                         0.0
# 996                           0.0                         1.0
# 997                           1.0                         0.0
# 998                           1.0                         0.0
# 999                           1.0                         0.0
#
#      OneHotEncoder__race_ethnicity_group A  \
# 750                                    0.0
# 751                                    0.0
# 752                                    0.0
# 753                                    0.0
# 754                                    0.0
# ..                                     ...
# 995                                    0.0
# 996                                    0.0
# 997                                    0.0
# 998                                    0.0
# 999                                    0.0
#
#      OneHotEncoder__race_ethnicity_group B  \
# 750                                    0.0
# 751                                    0.0
# 752                                    0.0
# 753                                    0.0
# 754                                    0.0
# ..                                     ...
# 995                                    0.0
# 996                                    0.0
# 997                                    0.0
# 998                                    0.0
# 999                                    0.0
#
#      OneHotEncoder__race_ethnicity_group C  \
# 750                                    0.0
# 751                                    0.0
# 752                                    1.0
# 753                                    1.0
# 754                                    1.0
# ..                                     ...
# 995                                    0.0
# 996                                    1.0
# 997                                    1.0
# 998                                    0.0
# 999                                    0.0
#
#      OneHotEncoder__race_ethnicity_group D  \
# 750                                    1.0
# 751                                    0.0
# 752                                    0.0
# 753                                    0.0
# 754                                    0.0
# ..                                     ...
# 995                                    0.0
# 996                                    0.0
# 997                                    0.0
# 998                                    1.0
# 999                                    1.0
#
#      OneHotEncoder__race_ethnicity_group E  \
# 750                                    0.0
# 751                                    1.0
# 752                                    0.0
# 753                                    0.0
# 754                                    0.0
# ..                                     ...
# 995                                    1.0
# 996                                    0.0
# 997                                    0.0
# 998                                    0.0
# 999                                    0.0
#
#      OneHotEncoder__parental_level_of_education_associate's degree  \
# 750                                                0.0
# 751                                                0.0
# 752                                                0.0
# 753                                                0.0
# 754                                                1.0
# ..                                                 ...
# 995                                                0.0
# 996                                                0.0
# 997                                                0.0
# 998                                                0.0
# 999                                                0.0
#
#      OneHotEncoder__parental_level_of_education_bachelor's degree  \
# 750                                                0.0
# 751                                                0.0
# 752                                                0.0
# 753                                                0.0
# 754                                                0.0
# ..                                                 ...
# 995                                                0.0
# 996                                                0.0
# 997                                                0.0
# 998                                                0.0
# 999                                                0.0
#
#      OneHotEncoder__parental_level_of_education_high school  \
# 750                                                0.0
# 751                                                0.0
# 752                                                0.0
# 753                                                0.0
# 754                                                0.0
# ..                                                 ...
# 995                                                0.0
# 996                                                1.0
# 997                                                1.0
# 998                                                0.0
# 999                                                0.0
#
#      OneHotEncoder__parental_level_of_education_master's degree  \
# 750                                                0.0
# 751                                                0.0
# 752                                                1.0
# 753                                                0.0
# 754                                                0.0
# ..                                                 ...
# 995                                                1.0
# 996                                                0.0
# 997                                                0.0
# 998                                                0.0
# 999                                                0.0
#
#      OneHotEncoder__parental_level_of_education_some college  \
# 750                                                0.0
# 751                                                1.0
# 752                                                0.0
# 753                                                0.0
# 754                                                0.0
# ..                                                 ...
# 995                                                0.0
# 996                                                0.0
# 997                                                0.0
# 998                                                1.0
# 999                                                1.0
#
#      OneHotEncoder__parental_level_of_education_some high school  \
# 750                                                1.0
# 751                                                0.0
# 752                                                0.0
# 753                                                1.0
# 754                                                0.0
# ..                                                 ...
# 995                                                0.0
# 996                                                0.0
# 997                                                0.0
# 998                                                0.0
# 999                                                0.0
#
#      OneHotEncoder__lunch_free/reduced  OneHotEncoder__lunch_standard  \
# 750                                0.0                            1.0
# 751                                0.0                            1.0
# 752                                1.0                            0.0
# 753                                0.0                            1.0
# 754                                1.0                            0.0
# ..                                 ...                            ...
# 995                                0.0                            1.0
# 996                                1.0                            0.0
# 997                                1.0                            0.0
# 998                                0.0                            1.0
# 999                                1.0                            0.0
#
#      OneHotEncoder__test_preparation_course_completed  \
# 750                                               1.0
# 751                                               0.0
# 752                                               1.0
# 753                                               1.0
# 754                                               0.0
# ..                                                ...
# 995                                               1.0
# 996                                               0.0
# 997                                               1.0
# 998                                               1.0
# 999                                               0.0
#
#      OneHotEncoder__test_preparation_course_none  \
# 750                                          0.0
# 751                                          1.0
# 752                                          0.0
# 753                                          0.0
# 754                                          1.0
# ..                                           ...
# 995                                          0.0
# 996                                          1.0
# 997                                          0.0
# 998                                          0.0
# 999                                          1.0
#
#      StandardScaler__reading_score  StandardScaler__writing_score
# 750                      -0.011581                      -0.003555
# 751                       0.193999                      -0.201079
# 752                       0.536631                       0.457333
# 753                       1.427476                       1.115745
# 754                      -0.970952                      -0.991174
# ..                             ...                            ...
# 995                       2.044215                       1.774157
# 996                      -0.970952                      -0.859491
# 997                       0.125472                      -0.201079
# 998                       0.605158                       0.589015
# 999                       1.153370                       1.181586
#
# [250 rows x 19 columns]

# %%
for model in models.keys():
    initialize=models[model]
    initialize.fit(xtrain,ytrain)
    print(f"For {model}")
    y_predict_train=initialize.predict(xtrain)
    y_predict_test=initialize.predict(xtest)
    print(f"for train")
    msetr,r2tr,maetr=metrics_evaluation(ytrain,y_predict_train)
    print(f"mean_squared_error for {model} train: {msetr}")
    print(f"r2_score for {model} train: {r2tr}")
    print(f"mean_absolute_error for {model} train: {maetr}")

    print("--------------------------------------------")
    print(f"for test")
    msete,r2te,maete=metrics_evaluation(ytest,y_predict_test)
    print(f"mean_squared_error for {model} test: {msete}")
    print(f"r2_score for {model} test: {r2te}")
    print(f"mean_absolute_error for {model} test: {maete}")
    print("---------------------------------------------")
    print()
    print()
# Out:
# For LinearRegression
# for train
# mean_squared_error for LinearRegression train: 27.796207356770832
# r2_score for LinearRegression train: 0.8628632544728445
# mean_absolute_error for LinearRegression train: 4.2145625
# --------------------------------------------
# for test
# mean_squared_error for LinearRegression test: 30.5203505859375
# r2_score for LinearRegression test: 0.840474693808369
# mean_absolute_error for LinearRegression test: 4.3570625
# ---------------------------------------------
#
#
# For LogisticRegression
# for train
# mean_squared_error for LogisticRegression train: 66.71466666666667
# r2_score for LogisticRegression train: 0.6067765538652465
# mean_absolute_error for LogisticRegression train: 5.914666666666666
# --------------------------------------------
# for test
# mean_squared_error for LogisticRegression test: 71.708
# r2_score for LogisticRegression test: 0.5208554436883404
# mean_absolute_error for LogisticRegression test: 6.66
# ---------------------------------------------
#
#
# For Ridge
# for train
# mean_squared_error for Ridge train: 27.78390482300972
# r2_score for Ridge train: 0.8636176588293003
# mean_absolute_error for Ridge train: 4.214341897871254
# --------------------------------------------
# for test
# mean_squared_error for Ridge test: 30.468881544996268
# r2_score for Ridge test: 0.8413804971933454
# mean_absolute_error for Ridge test: 4.345713153708029
# ---------------------------------------------
#
#
# For SVR
# for train
# mean_squared_error for SVR train: 48.611027586786214
# r2_score for SVR train: 0.6071238434846056
# mean_absolute_error for SVR train: 4.930062823864986
# --------------------------------------------
# for test
# mean_squared_error for SVR test: 46.740947529785934
# r2_score for SVR test: 0.6059295645487135
# mean_absolute_error for SVR test: 5.276944181637356
# ---------------------------------------------
#
#
# For NaiveBayes
# for train
# mean_squared_error for NaiveBayes train: 440.22933333333333
# r2_score for NaiveBayes train: 0.3740437416602391
# mean_absolute_error for NaiveBayes train: 17.506666666666668
# --------------------------------------------
# for test
# mean_squared_error for NaiveBayes test: 523.316
# r2_score for NaiveBayes test: 0.2565165574454261
# mean_absolute_error for NaiveBayes test: 19.636
# ---------------------------------------------
#
#
# For KNeighborsRegressor
# for train
# mean_squared_error for KNeighborsRegressor train: 33.22906666666667
# r2_score for KNeighborsRegressor train: 0.8055853931357073
# mean_absolute_error for KNeighborsRegressor train: 4.5687999999999995
# --------------------------------------------
# for test
# mean_squared_error for KNeighborsRegressor test: 57.52816000000001
# r2_score for KNeighborsRegressor test: 0.5813059557618756
# mean_absolute_error for KNeighborsRegressor test: 6.0984
# ---------------------------------------------
#
#
# For DecisionTreeRegressor
# for train
# mean_squared_error for DecisionTreeRegressor train: 0.14733333333333334
# r2_score for DecisionTreeRegressor train: 0.9993650263841785
# mean_absolute_error for DecisionTreeRegressor train: 0.025333333333333333
# --------------------------------------------
# for test
# mean_squared_error for DecisionTreeRegressor test: 63.804
# r2_score for DecisionTreeRegressor test: 0.6981498407580031
# mean_absolute_error for DecisionTreeRegressor test: 6.452
# ---------------------------------------------
#
#
# For RandomForestRegressor
# for train
# mean_squared_error for RandomForestRegressor train: 5.444217686123961
# r2_score for RandomForestRegressor train: 0.9743673656722417
# mean_absolute_error for RandomForestRegressor train: 1.8150069206349209
# --------------------------------------------
# for test
# mean_squared_error for RandomForestRegressor test: 36.19558964722222
# r2_score for RandomForestRegressor test: 0.7970657865243611
# mean_absolute_error for RandomForestRegressor test: 4.886183333333332
# ---------------------------------------------
#
#
# For AdaBoostRegressor
# for train
# mean_squared_error for AdaBoostRegressor train: 32.54086858035217
# r2_score for AdaBoostRegressor train: 0.826302250725111
# mean_absolute_error for AdaBoostRegressor train: 4.619420377726394
# --------------------------------------------
# for test
# mean_squared_error for AdaBoostRegressor test: 38.80485672321877
# r2_score for AdaBoostRegressor test: 0.7607290759440061
# mean_absolute_error for AdaBoostRegressor test: 5.003549583875429
# ---------------------------------------------
#
#
# For XGBRegressor
# for train
# mean_squared_error for XGBRegressor train: 0.8376895294474253
# r2_score for XGBRegressor train: 0.9963130707581884
# mean_absolute_error for XGBRegressor train: 0.5914503785769145
# --------------------------------------------
# for test
# mean_squared_error for XGBRegressor test: 41.35442884505053
# r2_score for XGBRegressor test: 0.7699941094137168
# mean_absolute_error for XGBRegressor test: 5.1865497512817385
# ---------------------------------------------
